# %%
import pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('starbucks_drinkMenu_expanded copy.csv')

# %%
df.head()
# Out:
#          Beverage_category       Beverage      Beverage_prep  Calories  \
# 0                   Coffee  Brewed Coffee              Short         3
# 1                   Coffee  Brewed Coffee               Tall         4
# 2                   Coffee  Brewed Coffee             Grande         5
# 3                   Coffee  Brewed Coffee              Venti         5
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
#
#    Total Fat  Trans Fat   Saturated Fat   Sodium   Total Carbohydrates  \
# 0        0.1         0.0            0.0        0                     5
# 1        0.1         0.0            0.0        0                    10
# 2        0.1         0.0            0.0        0                    10
# 3        0.1         0.0            0.0        0                    10
# 4        0.1         0.1            0.0        5                    75
#
#    Cholesterol   Dietary Fibre   Sugars   Protein VitaminA VitaminC  Calcium  \
# ...

# %%
df.dtypes
# Out:
# Beverage_category        object
# Beverage                 object
# Beverage_prep            object
# Calories                  int64
#  Total Fat               object
# Trans Fat               float64
# Saturated Fat           float64
#  Sodium                   int64
#  Total Carbohydrates      int64
# Cholesterol               int64
#  Dietary Fibre            int64
#  Sugars                   int64
#  Protein                float64
# VitaminA                 object
# VitaminC                 object
#  Calcium                 object
# Iron                     object
# Caffeine                float64
# dtype: object

# %%
df.Beverage
# Out:
# 0                                     Brewed Coffee
# 1                                     Brewed Coffee
# 2                                     Brewed Coffee
# 3                                     Brewed Coffee
# 4                                       Caffè Latte
#                            ...
# 237    Strawberries & Crème (Without Whipped Cream)
# 238            Vanilla Bean (Without Whipped Cream)
# 239            Vanilla Bean (Without Whipped Cream)
# 240            Vanilla Bean (Without Whipped Cream)
# 241            Vanilla Bean (Without Whipped Cream)
# Name: Beverage, Length: 242, dtype: object

# %%
#df =(df[df.Caffeine != 'vaires'])

# %%
#df_caf= df[(df.Caffeine !='vaires') | (df.Caffeine !='Varies')]

# %%
#df2 = df[df['Caffeine'] ~df.isin(['Mangos', 'Grapes']) ]

# %%
#df.sort_values(by='Caffeine',ascending=False).head(10)

# %%
#df[df.Caffeine !='varies'].Caffeine.sort_values(ascending=False)

# %%
df.Caffeine.sort_values(ascending=False).head()
# Out:
# 3      410.0
# 2      330.0
# 43     300.0
# 1      260.0
# 156    235.0
# Name: Caffeine, dtype: float64

# %%
df.sort_values(by='Caffeine', ascending=False).head(10)
# Out:
#            Beverage_category                                 Beverage  \
# 3                     Coffee                            Brewed Coffee
# 2                     Coffee                            Brewed Coffee
# 43   Classic Espresso Drinks                          Caffè Americano
# 1                     Coffee                            Brewed Coffee
# 156    Shaken Iced Beverages  Iced Brewed Coffee (With Classic Syrup)
# 42   Classic Espresso Drinks                          Caffè Americano
# 27   Classic Espresso Drinks      Caffè Mocha (Without Whipped Cream)
# 26   Classic Espresso Drinks      Caffè Mocha (Without Whipped Cream)
# 25   Classic Espresso Drinks      Caffè Mocha (Without Whipped Cream)
# 22   Classic Espresso Drinks      Caffè Mocha (Without Whipped Cream)
#
#           Beverage_prep  Calories  Total Fat  Trans Fat   Saturated Fat  \
# 3                 Venti         5        0.1         0.0            0.0
# ...

# %%
df.dtypes
# Out:
# Beverage_category        object
# Beverage                 object
# Beverage_prep            object
# Calories                  int64
#  Total Fat               object
# Trans Fat               float64
# Saturated Fat           float64
#  Sodium                   int64
#  Total Carbohydrates      int64
# Cholesterol               int64
#  Dietary Fibre            int64
#  Sugars                   int64
#  Protein                float64
# VitaminA                 object
# VitaminC                 object
#  Calcium                 object
# Iron                     object
# Caffeine                float64
# dtype: object

# %%
#removed a space in front of column name. 
df.columns = df.columns.str.lstrip()

# %%
df.sort_values(by='Sugars',ascending=False).head(10)
# Out:
#                Beverage_category  \
# 214  Frappuccino® Blended Coffee
# 215  Frappuccino® Blended Coffee
# 101    Signature Espresso Drinks
# 216  Frappuccino® Blended Coffee
# 206  Frappuccino® Blended Coffee
# 205  Frappuccino® Blended Coffee
# 196  Frappuccino® Blended Coffee
# 197  Frappuccino® Blended Coffee
# 83     Signature Espresso Drinks
# 84     Signature Espresso Drinks
#
#                                           Beverage      Beverage_prep  \
# 214              Java Chip (Without Whipped Cream)  Venti Nonfat Milk
# 215              Java Chip (Without Whipped Cream)         Whole Milk
# 101    Caramel Apple Spice (Without Whipped Cream)              Venti
# 216              Java Chip (Without Whipped Cream)            Soymilk
# 206                Caramel (Without Whipped Cream)         Whole Milk
# 205                Caramel (Without Whipped Cream)  Venti Nonfat Milk
# 196                  Mocha (Without Whipped Cream)  Venti Nonfat Milk
# ...

# %%
df[['Beverage','Sugars']].sort_values(by='Sugars', ascending=False).head(10).plot(kind='barh', x='Beverage',y='Sugars')
# Out:
# <AxesSubplot:ylabel='Beverage'>

# %%
df.Sugars.median()
# Out:
# 32.0

# %%
df.Protein.median()
# Out:
# 6.0

# %%
df.Calories.median()
# Out:
# 185.0

# %%
df.Sodium.median()
# Out:
# 5.0

# %%
df.Iron
# Out:
# 0       0%
# 1       0%
# 2       0%
# 3       0%
# 4       0%
#       ...
# 237    10%
# 238     0%
# 239     0%
# 240     6%
# 241     0%
# Name: Iron, Length: 242, dtype: object

# %%
df.sort_values(by='Calories', ascending=False).head(15)
# Out:
#                Beverage_category  \
# 84     Signature Espresso Drinks
# 215  Frappuccino® Blended Coffee
# 85     Signature Espresso Drinks
# 83     Signature Espresso Drinks
# 128             Tazo® Tea Drinks
# 216  Frappuccino® Blended Coffee
# 214  Frappuccino® Blended Coffee
# 81     Signature Espresso Drinks
# 129             Tazo® Tea Drinks
# 197  Frappuccino® Blended Coffee
# 96     Signature Espresso Drinks
# 127             Tazo® Tea Drinks
# 82     Signature Espresso Drinks
# 206  Frappuccino® Blended Coffee
# 101    Signature Espresso Drinks
#
#                                           Beverage      Beverage_prep  \
# 84   White Chocolate Mocha (Without Whipped Cream)            2% Milk
# 215              Java Chip (Without Whipped Cream)         Whole Milk
# 85   White Chocolate Mocha (Without Whipped Cream)            Soymilk
# 83   White Chocolate Mocha (Without Whipped Cream)  Venti Nonfat Milk
# 128                          Tazo® Green Tea Latte            2% Milk
# ...

# %%
df.sort_values(by='Calories',ascending=False).head(10).plot(kind='barh', x='Beverage', y='Calories')
# Out:
# <AxesSubplot:ylabel='Beverage'>

# %%
df.plot.scatter(x='Beverage', y='Calories')
# Out:
# <AxesSubplot:xlabel='Beverage', ylabel='Calories'>

# %%
df.Beverage_prep.value_counts()
# Out:
# Soymilk               66
# 2% Milk               50
# Grande Nonfat Milk    26
# Tall Nonfat Milk      23
# Venti Nonfat Milk     22
# Whole Milk            16
# Short Nonfat Milk     12
# Grande                 7
# Venti                  7
# Tall                   7
# Short                  4
# Solo                   1
# Doppio                 1
# Name: Beverage_prep, dtype: int64

# %%
df.plot.scatter(x='Sodium', y='Calories')
# Out:
# <AxesSubplot:xlabel='Sodium', ylabel='Calories'>

# %%
df.sort_values(by='VitaminC', ascending=False).head(10)
# Out:
#               Beverage_category                                      Beverage  \
# 177                   Smoothies                  Orange Mango Banana Smoothie
# 176                   Smoothies                  Orange Mango Banana Smoothie
# 175                   Smoothies                  Orange Mango Banana Smoothie
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 236  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 235  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 232  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 119            Tazo® Tea Drinks                         Tazo® Green Tea Latte
# 230  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 231  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
#
#           Beverage_prep  Calories Total Fat  Trans Fat   Saturated Fat  \
# ...

# %%
#df.groupby(by="VitaminC").plot(kind='barh', x="VitaminC", y="Protein")
# Out:
# VitaminC
# 0%      AxesSubplot(0.125,0.125;0.775x0.755)
# 10%     AxesSubplot(0.125,0.125;0.775x0.755)
# 100%    AxesSubplot(0.125,0.125;0.775x0.755)
# 15%     AxesSubplot(0.125,0.125;0.775x0.755)
# 2%      AxesSubplot(0.125,0.125;0.775x0.755)
# 20%     AxesSubplot(0.125,0.125;0.775x0.755)
# 4%      AxesSubplot(0.125,0.125;0.775x0.755)
# 6%      AxesSubplot(0.125,0.125;0.775x0.755)
# 8%      AxesSubplot(0.125,0.125;0.775x0.755)
# 80%     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.sort_values(by='Protein', ascending=False).head(10)
# Out:
#              Beverage_category                                       Beverage  \
# 172                  Smoothies                      Banana Chocolate Smoothie
# 173                  Smoothies                      Banana Chocolate Smoothie
# 174                  Smoothies                      Banana Chocolate Smoothie
# 83   Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# 84   Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# 95   Signature Espresso Drinks          Hot Chocolate (Without Whipped Cream)
# 127           Tazo® Tea Drinks                          Tazo® Green Tea Latte
# 96   Signature Espresso Drinks          Hot Chocolate (Without Whipped Cream)
# 25     Classic Espresso Drinks            Caffè Mocha (Without Whipped Cream)
# 128           Tazo® Tea Drinks                          Tazo® Green Tea Latte
#
#           Beverage_prep  Calories Total Fat  Trans Fat   Saturated Fat  \
# ...
